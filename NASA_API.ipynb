# %%
import requests
import json  # the NASA api's respond with json

# %%
# setup the URL part
base_url = "https://api.nasa.gov/neo/rest/v1/"
endpoint = "feed"

# %%
# setup query parameters.
start = "2020-10-01"
end = "2020-10-01"
with open('apikey.txt', 'r') as keyfile:
  apikey = keyfile.read()

# %%
# build and execute the request using the base URL, plus endpoint, plus query parameters
url = base_url + endpoint
query_params = {"start_date": start, "end_date": end, "api_key": apikey}
response = requests.get(url=url, params=query_params)

# %%
print("Now fetching: " + response.url) # print the URL that ultimately got constructed and requested
# Out:
# Now fetching: https://api.nasa.gov/neo/rest/v1/feed?start_date=2020-10-01&end_date=2020-10-01&api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt

# %%
if response.status_code == 200:
  print('Success')
  response_string = json.loads(response.text) # load the string version of the response to a json object
  print(json.dumps(response_string, indent=2))
# Out:
# Success
# {
#   "links": {
#     "next": "http://www.neowsapp.com/rest/v1/feed?start_date=2020-10-02&end_date=2020-10-02&detailed=false&api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt",
#     "prev": "http://www.neowsapp.com/rest/v1/feed?start_date=2020-09-30&end_date=2020-09-30&detailed=false&api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt",
#     "self": "http://www.neowsapp.com/rest/v1/feed?start_date=2020-10-01&end_date=2020-10-01&detailed=false&api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#   },
#   "element_count": 21,
#   "near_earth_objects": {
#     "2020-10-01": [
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/54054781?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "54054781",
#         "neo_reference_id": "54054781",
#         "name": "(2020 TR)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54054781",
#         "absolute_magnitude_h": 24.612,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0317800793,
#             "estimated_diameter_max": 0.0710624177
#           },
#           "meters": {
#             "estimated_diameter_min": 31.7800793037,
#             "estimated_diameter_max": 71.0624176534
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0197472197,
#             "estimated_diameter_max": 0.0441561255
#           },
#           "feet": {
#             "estimated_diameter_min": 104.2653553827,
#             "estimated_diameter_max": 233.1444223339
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": "2020-Oct-01 10:01",
#             "epoch_date_close_approach": 1601546460000,
#             "relative_velocity": {
#               "kilometers_per_second": "6.1671464414",
#               "kilometers_per_hour": "22201.7271891213",
#               "miles_per_hour": "13795.2898748182"
#             },
#             "miss_distance": {
#               "astronomical": "0.0232906295",
#               "lunar": "9.0600548755",
#               "kilometers": "3484228.564159165",
#               "miles": "2164999.237419877"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/54054324?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "54054324",
#         "neo_reference_id": "54054324",
#         "name": "(2020 RS6)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54054324",
#         "absolute_magnitude_h": 23.699,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0483899281,
#             "estimated_diameter_max": 0.1082031686
#           },
#           "meters": {
#             "estimated_diameter_min": 48.3899280769,
#             "estimated_diameter_max": 108.2031686062
#           },
#           "miles": {
#             "estimated_diameter_min": 0.030068098,
#             "estimated_diameter_max": 0.0672343111
#           },
#           "feet": {
#             "estimated_diameter_min": 158.7596116317,
#             "estimated_diameter_max": 354.9972836901
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": "2020-Oct-01 18:06",
#             "epoch_date_close_approach": 1601575560000,
#             "relative_velocity": {
#               "kilometers_per_second": "6.542437937",
#               "kilometers_per_hour": "23552.776573113",
#               "miles_per_hour": "14634.7794212212"
#             },
#             "miss_distance": {
#               "astronomical": "0.1986273606",
#               "lunar": "77.2660432734",
#               "kilometers": "29714230.069481922",
#               "miles": "18463566.3982256436"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/54054686?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "54054686",
#         "neo_reference_id": "54054686",
#         "name": "(2020 SU5)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54054686",
#         "absolute_magnitude_h": 26.795,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0116293376,
#             "estimated_diameter_max": 0.0260039893
#           },
#           "meters": {
#             "estimated_diameter_min": 11.6293375551,
#             "estimated_diameter_max": 26.0039893065
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0072261331,
#             "estimated_diameter_max": 0.0161581248
#           },
#           "feet": {
#             "estimated_diameter_min": 38.1539958243,
#             "estimated_diameter_max": 85.3149282764
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": "2020-Oct-01 03:15",
#             "epoch_date_close_approach": 1601522100000,
#             "relative_velocity": {
#               "kilometers_per_second": "9.4071078036",
#               "kilometers_per_hour": "33865.5880930856",
#               "miles_per_hour": "21042.7594459509"
#             },
#             "miss_distance": {
#               "astronomical": "0.0139188545",
#               "lunar": "5.4144344005",
#               "kilometers": "2082230.986039915",
#               "miles": "1293838.338644227"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/3838127?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "3838127",
#         "neo_reference_id": "3838127",
#         "name": "(2019 CR1)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3838127",
#         "absolute_magnitude_h": 23.8,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.046190746,
#             "estimated_diameter_max": 0.1032856481
#           },
#           "meters": {
#             "estimated_diameter_min": 46.1907460282,
#             "estimated_diameter_max": 103.2856480504
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0287015901,
#             "estimated_diameter_max": 0.0641787064
#           },
#           "feet": {
#             "estimated_diameter_min": 151.544447199,
#             "estimated_diameter_max": 338.8636855496
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": "2020-Oct-01 21:28",
#             "epoch_date_close_approach": 1601587680000,
#             "relative_velocity": {
#               "kilometers_per_second": "15.4205468891",
#               "kilometers_per_hour": "55513.9688009112",
#               "miles_per_hour": "34494.2213363217"
#             },
#             "miss_distance": {
#               "astronomical": "0.2247483006",
#               "lunar": "87.4270889334",
#               "kilometers": "33621867.055879722",
#               "miles": "20891659.4294032836"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/3076774?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "3076774",
#         "neo_reference_id": "3076774",
#         "name": "(2001 GP2)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3076774",
#         "absolute_magnitude_h": 26.9,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0110803882,
#             "estimated_diameter_max": 0.0247765013
#           },
#           "meters": {
#             "estimated_diameter_min": 11.0803882126,
#             "estimated_diameter_max": 24.7765012606
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0068850319,
#             "estimated_diameter_max": 0.0153953994
#           },
#           "feet": {
#             "estimated_diameter_min": 36.3529808636,
#             "estimated_diameter_max": 81.2877363957
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": "2020-Oct-01 14:59",
#             "epoch_date_close_approach": 1601564340000,
#             "relative_velocity": {
#               "kilometers_per_second": "2.2141412716",
#               "kilometers_per_hour": "7970.9085778251",
#               "miles_per_hour": "4952.8126104825"
#             },
#             "miss_distance": {
#               "astronomical": "0.0156459036",
#               "lunar": "6.0862565004",
#               "kilometers": "2340593.852785332",
#               "miles": "1454377.5797363016"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/3630637?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "3630637",
#         "neo_reference_id": "3630637",
#         "name": "(2013 ET9)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3630637",
#         "absolute_magnitude_h": 21.1,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.160160338,
#             "estimated_diameter_max": 0.358129403
#           },
#           "meters": {
#             "estimated_diameter_min": 160.1603379786,
#             "estimated_diameter_max": 358.1294030194
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0995189894,
#             "estimated_diameter_max": 0.2225312253
#           },
#           "feet": {
#             "estimated_diameter_min": 525.4604432536,
#             "estimated_diameter_max": 1174.9652706022
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": null,
#             "epoch_date_close_approach": 1601535600000,
#             "relative_velocity": {
#               "kilometers_per_second": "7.4692040802",
#               "kilometers_per_hour": "26889.1346888239",
#               "miles_per_hour": "16707.862607064"
#             },
#             "miss_distance": {
#               "astronomical": "0.3192837796",
#               "lunar": "124.2013902644",
#               "kilometers": "47764173.353709452",
#               "miles": "29679281.0754443576"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/3666733?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "3666733",
#         "neo_reference_id": "3666733",
#         "name": "(2014 FA44)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3666733",
#         "absolute_magnitude_h": 24.8,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0291443905,
#             "estimated_diameter_max": 0.0651688382
#           },
#           "meters": {
#             "estimated_diameter_min": 29.1443904535,
#             "estimated_diameter_max": 65.1688382168
#           },
#           "miles": {
#             "estimated_diameter_min": 0.018109479,
#             "estimated_diameter_max": 0.0404940262
#           },
#           "feet": {
#             "estimated_diameter_min": 95.6180819754,
#             "estimated_diameter_max": 213.8085311752
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": "2020-Oct-01 22:17",
#             "epoch_date_close_approach": 1601590620000,
#             "relative_velocity": {
#               "kilometers_per_second": "6.8711089455",
#               "kilometers_per_hour": "24735.9922038071",
#               "miles_per_hour": "15369.9836001933"
#             },
#             "miss_distance": {
#               "astronomical": "0.4609849418",
#               "lunar": "179.3231423602",
#               "kilometers": "68962365.395353966",
#               "miles": "42851226.8188820908"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/2482718?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "2482718",
#         "neo_reference_id": "2482718",
#         "name": "482718 (2013 ET9)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2482718",
#         "absolute_magnitude_h": 21.1,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.160160338,
#             "estimated_diameter_max": 0.358129403
#           },
#           "meters": {
#             "estimated_diameter_min": 160.1603379786,
#             "estimated_diameter_max": 358.1294030194
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0995189894,
#             "estimated_diameter_max": 0.2225312253
#           },
#           "feet": {
#             "estimated_diameter_min": 525.4604432536,
#             "estimated_diameter_max": 1174.9652706022
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": "2020-Oct-01 20:54",
#             "epoch_date_close_approach": 1601585640000,
#             "relative_velocity": {
#               "kilometers_per_second": "7.4692040902",
#               "kilometers_per_hour": "26889.1347247147",
#               "miles_per_hour": "16707.8626293651"
#             },
#             "miss_distance": {
#               "astronomical": "0.3192840994",
#               "lunar": "124.2015146666",
#               "kilometers": "47764221.195108278",
#               "miles": "29679310.8027111164"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/3651153?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "3651153",
#         "neo_reference_id": "3651153",
#         "name": "(2013 TR132)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3651153",
#         "absolute_magnitude_h": 20.1,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.2538370294,
#             "estimated_diameter_max": 0.5675968529
#           },
#           "meters": {
#             "estimated_diameter_min": 253.8370293645,
#             "estimated_diameter_max": 567.5968528656
#           },
#           "miles": {
#             "estimated_diameter_min": 0.1577269688,
#             "estimated_diameter_max": 0.3526882241
#           },
#           "feet": {
#             "estimated_diameter_min": 832.7986794202,
#             "estimated_diameter_max": 1862.1944587557
#           }
#         },
#         "is_potentially_hazardous_asteroid": true,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": "2020-Oct-01 09:23",
#             "epoch_date_close_approach": 1601544180000,
#             "relative_velocity": {
#               "kilometers_per_second": "19.5983924875",
#               "kilometers_per_hour": "70554.2129551631",
#               "miles_per_hour": "43839.6441553901"
#             },
#             "miss_distance": {
#               "astronomical": "0.3967147793",
#               "lunar": "154.3220491477",
#               "kilometers": "59347685.980800091",
#               "miles": "36876942.0619436158"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/54053919?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "54053919",
#         "neo_reference_id": "54053919",
#         "name": "(2020 RJ3)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54053919",
#         "absolute_magnitude_h": 23.467,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0538461897,
#             "estimated_diameter_max": 0.1204037404
#           },
#           "meters": {
#             "estimated_diameter_min": 53.8461896654,
#             "estimated_diameter_max": 120.4037404213
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0334584607,
#             "estimated_diameter_max": 0.0748153926
#           },
#           "feet": {
#             "estimated_diameter_min": 176.660732902,
#             "estimated_diameter_max": 395.0254077238
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": "2020-Oct-01 09:33",
#             "epoch_date_close_approach": 1601544780000,
#             "relative_velocity": {
#               "kilometers_per_second": "15.4563876044",
#               "kilometers_per_hour": "55642.9953757885",
#               "miles_per_hour": "34574.3934322504"
#             },
#             "miss_distance": {
#               "astronomical": "0.0390912307",
#               "lunar": "15.2064887423",
#               "kilometers": "5847964.848398609",
#               "miles": "3633756.8572504442"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/2303262?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "2303262",
#         "neo_reference_id": "2303262",
#         "name": "303262 (2004 RJ84)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2303262",
#         "absolute_magnitude_h": 18.6,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.5064714588,
#             "estimated_diameter_max": 1.1325046106
#           },
#           "meters": {
#             "estimated_diameter_min": 506.4714588346,
#             "estimated_diameter_max": 1132.5046106177
#           },
#           "miles": {
#             "estimated_diameter_min": 0.3147066768,
#             "estimated_diameter_max": 0.7037055224
#           },
#           "feet": {
#             "estimated_diameter_min": 1661.651821003,
#             "estimated_diameter_max": 3715.566426699
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": "2020-Oct-01 15:41",
#             "epoch_date_close_approach": 1601566860000,
#             "relative_velocity": {
#               "kilometers_per_second": "10.2404967412",
#               "kilometers_per_hour": "36865.7882683672",
#               "miles_per_hour": "22906.9671604196"
#             },
#             "miss_distance": {
#               "astronomical": "0.4272815093",
#               "lunar": "166.2125071177",
#               "kilometers": "63920403.681665191",
#               "miles": "39718297.0858779958"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/3251512?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "3251512",
#         "neo_reference_id": "3251512",
#         "name": "(2004 RX10)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3251512",
#         "absolute_magnitude_h": 21.3,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.1460679643,
#             "estimated_diameter_max": 0.3266178974
#           },
#           "meters": {
#             "estimated_diameter_min": 146.0679642714,
#             "estimated_diameter_max": 326.6178974458
#           },
#           "miles": {
#             "estimated_diameter_min": 0.090762397,
#             "estimated_diameter_max": 0.2029508896
#           },
#           "feet": {
#             "estimated_diameter_min": 479.2256199,
#             "estimated_diameter_max": 1071.581062656
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": null,
#             "epoch_date_close_approach": 1601535600000,
#             "relative_velocity": {
#               "kilometers_per_second": "23.2359178463",
#               "kilometers_per_hour": "83649.3042467851",
#               "miles_per_hour": "51976.4246304538"
#             },
#             "miss_distance": {
#               "astronomical": "0.4351230809",
#               "lunar": "169.2628784701",
#               "kilometers": "65093486.090477683",
#               "miles": "40447216.6942627054"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/2443837?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "2443837",
#         "neo_reference_id": "2443837",
#         "name": "443837 (2000 TJ1)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2443837",
#         "absolute_magnitude_h": 19.5,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.3346223745,
#             "estimated_diameter_max": 0.7482383761
#           },
#           "meters": {
#             "estimated_diameter_min": 334.6223744549,
#             "estimated_diameter_max": 748.2383760735
#           },
#           "miles": {
#             "estimated_diameter_min": 0.2079246394,
#             "estimated_diameter_max": 0.464933628
#           },
#           "feet": {
#             "estimated_diameter_min": 1097.8424710066,
#             "estimated_diameter_max": 2454.8503937571
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": "2020-Oct-01 13:57",
#             "epoch_date_close_approach": 1601560620000,
#             "relative_velocity": {
#               "kilometers_per_second": "19.3233604639",
#               "kilometers_per_hour": "69564.0976700324",
#               "miles_per_hour": "43224.4250216932"
#             },
#             "miss_distance": {
#               "astronomical": "0.2115841635",
#               "lunar": "82.3062396015",
#               "kilometers": "31652540.185331745",
#               "miles": "19667976.454978281"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/2523605?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "2523605",
#         "neo_reference_id": "2523605",
#         "name": "523605 (2004 RX10)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2523605",
#         "absolute_magnitude_h": 21.3,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.1460679643,
#             "estimated_diameter_max": 0.3266178974
#           },
#           "meters": {
#             "estimated_diameter_min": 146.0679642714,
#             "estimated_diameter_max": 326.6178974458
#           },
#           "miles": {
#             "estimated_diameter_min": 0.090762397,
#             "estimated_diameter_max": 0.2029508896
#           },
#           "feet": {
#             "estimated_diameter_min": 479.2256199,
#             "estimated_diameter_max": 1071.581062656
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": "2020-Oct-01 21:27",
#             "epoch_date_close_approach": 1601587620000,
#             "relative_velocity": {
#               "kilometers_per_second": "23.2359417701",
#               "kilometers_per_hour": "83649.3903722812",
#               "miles_per_hour": "51976.4781454877"
#             },
#             "miss_distance": {
#               "astronomical": "0.4351240143",
#               "lunar": "169.2632415627",
#               "kilometers": "65093625.725129541",
#               "miles": "40447303.4592120258"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/3892678?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "3892678",
#         "neo_reference_id": "3892678",
#         "name": "(2019 VT2)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3892678",
#         "absolute_magnitude_h": 24.3,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0366906138,
#             "estimated_diameter_max": 0.0820427065
#           },
#           "meters": {
#             "estimated_diameter_min": 36.6906137531,
#             "estimated_diameter_max": 82.0427064882
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0227984834,
#             "estimated_diameter_max": 0.0509789586
#           },
#           "feet": {
#             "estimated_diameter_min": 120.3760332259,
#             "estimated_diameter_max": 269.1689931548
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": "2020-Oct-01 19:19",
#             "epoch_date_close_approach": 1601579940000,
#             "relative_velocity": {
#               "kilometers_per_second": "6.5286009516",
#               "kilometers_per_hour": "23502.9634257745",
#               "miles_per_hour": "14603.8274686431"
#             },
#             "miss_distance": {
#               "astronomical": "0.2706551073",
#               "lunar": "105.2848367397",
#               "kilometers": "40489427.556701451",
#               "miles": "25158963.6470879838"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/54016425?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "54016425",
#         "neo_reference_id": "54016425",
#         "name": "(2020 FW6)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54016425",
#         "absolute_magnitude_h": 23.258,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0592863859,
#             "estimated_diameter_max": 0.132568389
#           },
#           "meters": {
#             "estimated_diameter_min": 59.2863859083,
#             "estimated_diameter_max": 132.5683890311
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0368388409,
#             "estimated_diameter_max": 0.0823741525
#           },
#           "feet": {
#             "estimated_diameter_min": 194.5091463432,
#             "estimated_diameter_max": 434.935673469
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": "2020-Oct-01 11:36",
#             "epoch_date_close_approach": 1601552160000,
#             "relative_velocity": {
#               "kilometers_per_second": "12.9286328229",
#               "kilometers_per_hour": "46543.0781623903",
#               "miles_per_hour": "28920.0587615141"
#             },
#             "miss_distance": {
#               "astronomical": "0.3338588362",
#               "lunar": "129.8710872818",
#               "kilometers": "49944570.776198894",
#               "miles": "31034117.2091929772"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/54054651?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "54054651",
#         "neo_reference_id": "54054651",
#         "name": "(2020 SB5)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54054651",
#         "absolute_magnitude_h": 24.717,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0302799377,
#             "estimated_diameter_max": 0.0677079989
#           },
#           "meters": {
#             "estimated_diameter_min": 30.2799376529,
#             "estimated_diameter_max": 67.7079989464
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0188150751,
#             "estimated_diameter_max": 0.042071787
#           },
#           "feet": {
#             "estimated_diameter_min": 99.3436306492,
#             "estimated_diameter_max": 222.1391112632
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": "2020-Oct-01 18:28",
#             "epoch_date_close_approach": 1601576880000,
#             "relative_velocity": {
#               "kilometers_per_second": "11.6870050734",
#               "kilometers_per_hour": "42073.2182642501",
#               "miles_per_hour": "26142.6616486947"
#             },
#             "miss_distance": {
#               "astronomical": "0.0790022103",
#               "lunar": "30.7318598067",
#               "kilometers": "11818562.386172061",
#               "miles": "7343714.1342180018"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/54054739?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "54054739",
#         "neo_reference_id": "54054739",
#         "name": "(2020 TA)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54054739",
#         "absolute_magnitude_h": 25.495,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0211619155,
#             "estimated_diameter_max": 0.0473194817
#           },
#           "meters": {
#             "estimated_diameter_min": 21.1619155341,
#             "estimated_diameter_max": 47.3194816683
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0131494006,
#             "estimated_diameter_max": 0.0294029536
#           },
#           "feet": {
#             "estimated_diameter_min": 69.4288589609,
#             "estimated_diameter_max": 155.2476482368
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": "2020-Oct-01 11:07",
#             "epoch_date_close_approach": 1601550420000,
#             "relative_velocity": {
#               "kilometers_per_second": "11.9070107239",
#               "kilometers_per_hour": "42865.238605905",
#               "miles_per_hour": "26634.792288208"
#             },
#             "miss_distance": {
#               "astronomical": "0.0014751318",
#               "lunar": "0.5738262702",
#               "kilometers": "220676.575249266",
#               "miles": "137122.0654252308"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/54054611?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "54054611",
#         "neo_reference_id": "54054611",
#         "name": "(2020 SM4)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54054611",
#         "absolute_magnitude_h": 27.662,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0078010844,
#             "estimated_diameter_max": 0.017443755
#           },
#           "meters": {
#             "estimated_diameter_min": 7.8010844008,
#             "estimated_diameter_max": 17.4437550184
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0048473676,
#             "estimated_diameter_max": 0.0108390435
#           },
#           "feet": {
#             "estimated_diameter_min": 25.5941097455,
#             "estimated_diameter_max": 57.2301692145
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": "2020-Oct-01 01:56",
#             "epoch_date_close_approach": 1601517360000,
#             "relative_velocity": {
#               "kilometers_per_second": "7.6179433409",
#               "kilometers_per_hour": "27424.5960273763",
#               "miles_per_hour": "17040.5774593439"
#             },
#             "miss_distance": {
#               "astronomical": "0.0209051292",
#               "lunar": "8.1320952588",
#               "kilometers": "3127362.800394804",
#               "miles": "1943253.1343201352"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/54054709?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "54054709",
#         "neo_reference_id": "54054709",
#         "name": "(2020 SN6)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54054709",
#         "absolute_magnitude_h": 28.79,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0046403953,
#             "estimated_diameter_max": 0.0103762393
#           },
#           "meters": {
#             "estimated_diameter_min": 4.6403952825,
#             "estimated_diameter_max": 10.3762392941
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0028834071,
#             "estimated_diameter_max": 0.0064474942
#           },
#           "feet": {
#             "estimated_diameter_min": 15.2243944585,
#             "estimated_diameter_max": 34.0427809255
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": "2020-Oct-01 13:14",
#             "epoch_date_close_approach": 1601558040000,
#             "relative_velocity": {
#               "kilometers_per_second": "5.7759444342",
#               "kilometers_per_hour": "20793.3999630843",
#               "miles_per_hour": "12920.2101048398"
#             },
#             "miss_distance": {
#               "astronomical": "0.006524259",
#               "lunar": "2.537936751",
#               "kilometers": "976015.24972833",
#               "miles": "606467.753897754"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://www.neowsapp.com/rest/v1/neo/54054715?api_key=ScYBFmr4rGgRclLQcKOeDS31buMmvxMgp6TRtaCt"
#         },
#         "id": "54054715",
#         "neo_reference_id": "54054715",
#         "name": "(2020 SW6)",
#         "nasa_jpl_url": "http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54054715",
#         "absolute_magnitude_h": 28.725,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0047813989,
#             "estimated_diameter_max": 0.010691533
#           },
#           "meters": {
#             "estimated_diameter_min": 4.7813988924,
#             "estimated_diameter_max": 10.691532951
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0029710226,
#             "estimated_diameter_max": 0.0066434085
#           },
#           "feet": {
#             "estimated_diameter_min": 15.6870047422,
#             "estimated_diameter_max": 35.0772089669
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2020-10-01",
#             "close_approach_date_full": "2020-Oct-01 12:30",
#             "epoch_date_close_approach": 1601555400000,
#             "relative_velocity": {
#               "kilometers_per_second": "2.1122501091",
#               "kilometers_per_hour": "7604.1003927154",
#               "miles_per_hour": "4724.8922690181"
#             },
#             "miss_distance": {
#               "astronomical": "0.0072092229",
#               "lunar": "2.8043877081",
#               "kilometers": "1078484.390195223",
#               "miles": "670139.1253031574"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       }
#     ]
#   }
# }
