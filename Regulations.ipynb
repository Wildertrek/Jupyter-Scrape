# %%
import requests
import json

# %% [markdown]
# Reference: https://open.gsa.gov/api/regulationsgov/
#
# ## API Description
# Regulations.gov offers a GET API for documents, comments, and dockets and a POST API for comments.
#
# These endpoints can be used for
# - searching documents,
# - comments,
# - dockets,
# - and posting a comment.
#
# ## Searching for documents
# You can search for a list of documents based on the criteria passed by using the endpoint __/v4/documents__. The search operation supports full text keyword searches and filtering based on a number of available parameters.
#
# ## You can also obtain detailed information for a single document
# In order to obtain more details about a single document, you can use the endpoint __/v4/documents/{documentId}__.
#
# A document is defined by one of the following types:
# - Proposed Rule,
# - Rule,
# - Supporting & Related,
# - or Other.
#
# Each document type has its own set of attributes, which vary based on the Agency posting the document.
#
# Another defining characteristic is if the document is part of a Rulemaking or Nonrulemaking Docket.
#
# You can choose to include attachments using __include__ parameter. Attachments are not included by default.
#
# ## Searching for comments
#
# You can search for a list of comments based on the criteria passed by using the endpoint __/v4/comments__. The search operation supports full text keyword searches and filtering based on a number of available parameters.
#
# ## Detailed information for a single comment
# In order to obtain more details about a single comment, you can use the endpoint __/v4/comments/{commentId}__.
#
# Each comment has its own set of attributes, which vary based on the Agency posting the comment.
#
# Another defining characteristic is if the comment is part of a Rulemaking or Nonrulemaking Docket.
#
# You can choose to include attachments using __include__ parameter. Attachments are not included by default.
#
# ## Searching for dockets
# A docket is an organizational folder containing multiple documents. Dockets can be searched using the endpoint: __/v4/dockets__.
#
# ## Detailed information for a single docket
# In order to obtain more details about a single docket, you can use the endpoint __/v4/dockets/{docketId}__.
#
# Each docket has its own set of attributes, which vary based on the Agency posting the docket. Another defining characteristic is if the docket is a Rulemaking or a Nonrulemaking Docket
#
# ## Posting a comment
# User can post a comment using the endpoint /v4/comments. User can post the comment using one of the following submitter types:
#
# __Individual__
# __Organization__
# __Anonymous__
#
# If user would like to attach files with their submission, user can get a presigned url for the amazon s3 bucket using the endpoint __/v4/file-upload-urls__
#
# A submissionKey can be retrieved using __/v4/submission-keys__ endpoint.
#
# submissionType should be set to API.
#
# - Search for term covid:
# ```https://api.regulations.gov/v4/documents?filter[searchTerm]=covid&api_key=DEMO_KEY```
# - Filter documents by a specific date:
# ```https://api.regulations.gov/v4/documents?filter[postedDate]=2020-09-01&api_key=DEMO_KEY```
# - Filter documents by a date range:
# ```https://api.regulations.gov/v4/documents?filter[postedDate][ge]=2020-09-01&filter[postedDate][le]=2020-09-01&api_key=DEMO_KEY```
# - Search for a documentId:
# ```https://api.regulations.gov/v4/documents?filter[searchTerm]=FDA-2009-N-0501-0012&api_key=DEMO_KEY```
# - Sort documents by posted date in asc:
# ```https://api.regulations.gov/v4/documents?sort=postedDate&api_key=DEMO_KEY```
# - Sort documents by posted date in desc:
# - ```https://api.regulations.gov/v4/documents?sort=-postedDate&api_key=DEMO_KEY```

# %%
# setup the base URL part and endpoint for document search
base_url = "https://api.regulations.gov/"
endpoint = "v4/documents?filter[searchTerm]=covid"

# %%
# setup query parameters.
# start = "2020-10-01"
# end = "2020-10-01"

with open('demoapikey.txt', 'r') as keyfile:
  apikey = keyfile.read()

# %%
# build and execute the request using the base URL, plus endpoint, plus query parameters
url = base_url + endpoint
#query_params = {"start_date": start, "end_date": end, "api_key": apikey}
query_params = {"api_key": apikey}
response = requests.get(url=url, params=query_params)

# %%
print("Now fetching: " + response.url) # print the URL that ultimately got constructed and requested
#             https://api.regulations.gov/v4/documents?filter[searchTerm]=covid&api_key=DEMO_KEY
# Out:
# Now fetching: https://api.regulations.gov/v4/documents?filter%5BsearchTerm%5D=covid&api_key=DEMO_KEY

# %%
if response.status_code == 200:
  print('Success')
  response_string = json.loads(response.text) # load the string version of the response to a json object
  print(json.dumps(response_string, indent=2))
# Out:
# Success
# {
#   "data": [
#     {
#       "id": "USTR-2020-0014-0633",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-04-22T04:00:00Z",
#         "highlightedContent": "Camp Chef <mark><em>COVID</em></mark> Comment",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-06-26T03:59:59Z",
#         "title": "Comment from Daniel Neumann, Camp Chef",
#         "openForComment": false,
#         "postedDate": "2020-04-22T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-0633"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-0756",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-05-19T04:00:00Z",
#         "highlightedContent": "Trace Zero 301 <mark><em>Covid</em></mark> Comments",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-06-26T03:59:59Z",
#         "title": "Comment from Trace Zero,",
#         "openForComment": false,
#         "postedDate": "2020-05-19T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-0756"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-1128",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-06-28T04:00:00Z",
#         "highlightedContent": "Mi-T-M <mark><em>COVID</em></mark> Submission Final&hellip;&nbsp;25jun20 - COVID-19 request on Power Washer Mister Combinations V3.pdf (p.1-6)\n\tMi-T-M Attachments to <mark><em>COVID</em></mark>",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-07-02T03:59:59Z",
#         "title": "Comment from Mi-T-M Corporation, Rock Trade Law, LLC",
#         "openForComment": false,
#         "postedDate": "2020-06-28T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-1128"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-0860",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-06-22T04:00:00Z",
#         "highlightedContent": "URBN - <mark><em>COVID</em></mark> exclusion request",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-06-26T03:59:59Z",
#         "title": "Comment from Jared Angle, URBN, Inc.",
#         "openForComment": false,
#         "postedDate": "2020-06-22T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-0860"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-0773",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-05-19T04:00:00Z",
#         "highlightedContent": "Digilock -- PackageHold and <mark><em>COVID</em></mark> (FINAL)",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-06-26T03:59:59Z",
#         "title": "Comment from Richard Mojica, Security People, Inc. d/b/a Digilock",
#         "openForComment": false,
#         "postedDate": "2020-05-19T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-0773"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-1002",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-06-26T04:00:00Z",
#         "highlightedContent": "Zep Compiled <mark><em>COVID</em></mark> Submission",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-07-02T03:59:59Z",
#         "title": "Comment from Matt  Duncan, Zep Inc.",
#         "openForComment": false,
#         "postedDate": "2020-06-26T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-1002"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-1119",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-06-28T04:00:00Z",
#         "highlightedContent": "Kollmorgen <mark><em>COVID</em></mark> 19 Comment",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-07-02T03:59:59Z",
#         "title": "Comment from Katie Bogue,",
#         "openForComment": false,
#         "postedDate": "2020-06-28T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-1119"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-1090",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-06-28T04:00:00Z",
#         "highlightedContent": "2020.06.25_Carestream USTR <mark><em>COVID</em></mark> Comments.v3&hellip;&nbsp;Washington, DC 20508 \n\n \n\nRE: Request for Comments on Additional Modifications to the 301 Action To Address <mark><em>COVID</em></mark>",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-07-02T03:59:59Z",
#         "title": "Comment from Rory Murphy,",
#         "openForComment": false,
#         "postedDate": "2020-06-28T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-1090"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-0572",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-04-16T04:00:00Z",
#         "highlightedContent": "<mark><em>covid</em></mark> - USTR - agiecharmilles-cut-e-350-600_en&hellip;&nbsp;<mark><em>Covid</em></mark> - USTR - mikron-mill-p-900_en&hellip;&nbsp;<mark><em>Covid</em></mark> - USTR - mikron-mill-e-u-series_en 500 700",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-06-26T03:59:59Z",
#         "title": "Comment from Brian Curtis,",
#         "openForComment": false,
#         "postedDate": "2020-04-16T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-0572"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-0981",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-06-26T04:00:00Z",
#         "highlightedContent": "HBI <mark><em>COVID</em></mark> USTR-2020-0014 EXHIBITS&hellip;&nbsp;Number USTR\u20132020\u20130014: Request for Comments on Additional Modifications to the 301 Action to \nAddress <mark><em>COVID</em></mark>&hellip;&nbsp;Number USTR\u20132020\u20130014: Request for Comments on Additional Modifications \nto the 301 Action to Address <mark><em>COVID</em></mark>&hellip;&nbsp;Number USTR\u20132020\u20130014: Request for Comments on Additional \nModifications to the 301 Action to Address <mark><em>COVID</em></mark>&hellip;&nbsp;With the <mark><em>COVID</em></mark> crisis, it has greatly impacted not only our clinicians, \nhospitals and patients, but&hellip;&nbsp;Number USTR\u20132020\u20130014: Request for Comments on Additional \nModifications to the 301 Action to Address <mark><em>COVID</em></mark>&hellip;&nbsp;HBI <mark><em>COVID</em></mark> USTR-2020-0014 (FILED Jun 25 20)",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-07-02T03:59:59Z",
#         "title": "Comment from Jo Ritcey-Donohue, Happiest Baby, Inc.",
#         "openForComment": false,
#         "postedDate": "2020-06-26T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-0981"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-0992",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-06-26T04:00:00Z",
#         "highlightedContent": "Novozymes <mark><em>COVID</em></mark> exclusion comments June",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-07-02T03:59:59Z",
#         "title": "Comment from Catherine Thorin,",
#         "openForComment": false,
#         "postedDate": "2020-06-26T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-0992"
#       }
#     },
#     {
#       "id": "FAA-2020-0412-0007",
#       "type": "documents",
#       "attributes": {
#         "docketId": "FAA-2020-0412",
#         "documentType": "Other",
#         "subtype": "Petition(s)",
#         "commentStartDate": "2020-07-22T04:00:00Z",
#         "highlightedContent": "AMOA Petition for Extension <mark><em>covid</em></mark> 0720",
#         "withdrawn": false,
#         "agencyId": "FAA",
#         "commentEndDate": null,
#         "title": "Air Medical Operators Association (AMOA) - Exemption/Rulemaking",
#         "openForComment": false,
#         "postedDate": "2020-07-22T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/FAA-2020-0412-0007"
#       }
#     },
#     {
#       "id": "EPA-HQ-OAR-2018-0195-0329",
#       "type": "documents",
#       "attributes": {
#         "docketId": "EPA-HQ-OAR-2018-0195",
#         "documentType": "Supporting & Related Material",
#         "subtype": "Public Hearing Transcript, Deposition, Testimony",
#         "commentStartDate": null,
#         "highlightedContent": "live\n10 near polluting sources will face multiple threats\n11 to their lungs at once, and even when the <mark><em>COVID</em></mark>&hellip;&nbsp;though the impact on larger retailers\n12 who have remained open is less clear.  \n13             Yet <mark><em>COVID</em></mark>&hellip;&nbsp;94:21\nCouncil 68:7\ncountless 94:22\ncountry 4:20 69:10 72:9\n\n79:17 114:11\ncourse 95:8\ncovered 33:17\n<mark><em>COVID</em></mark>",
#         "withdrawn": false,
#         "agencyId": "EPA",
#         "commentEndDate": null,
#         "title": "Wood Heater COVID Public Hearing Transcript 06082020",
#         "openForComment": false,
#         "postedDate": "2020-09-23T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2018-0195-0329"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-0685",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-04-28T04:00:00Z",
#         "highlightedContent": "Rexnord - USTR <mark><em>COVID</em></mark> Relief Request - Roller Bearings",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-06-26T03:59:59Z",
#         "title": "Comment from Ana  Esper, Rexnord Industries, LLC",
#         "openForComment": false,
#         "postedDate": "2020-04-28T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-0685"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-0689",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-05-04T04:00:00Z",
#         "highlightedContent": "Rexnord - USTR <mark><em>COVID</em></mark> Relief Request - Industrial Chain",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-06-26T03:59:59Z",
#         "title": "Comment from Ana  Esper, Rexnord Industries, LLC",
#         "openForComment": false,
#         "postedDate": "2020-05-04T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-0689"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-0811",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-06-08T04:00:00Z",
#         "highlightedContent": "Section 301- <mark><em>COVID</em></mark> Exclusions-Generator NARRATIVE(9537731.1)&hellip;&nbsp;play a \n\ncritical role in helping to keep our communities safe and healthy and reduce the spread of <mark><em>COVID</em></mark>",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-06-26T03:59:59Z",
#         "title": "Comment from Gina Vollmer,",
#         "openForComment": false,
#         "postedDate": "2020-06-08T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-0811"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-1091",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-06-28T04:00:00Z",
#         "highlightedContent": "51039419_v 1_Positec - KN95 Masks - 301 <mark><em>COVID</em></mark> Req.pdf",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-07-02T03:59:59Z",
#         "title": "Comment from _ Positec USA, Inc. , Greenberg Traurig, LLP",
#         "openForComment": false,
#         "postedDate": "2020-06-28T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-1091"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-1001",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-06-26T04:00:00Z",
#         "highlightedContent": "Section 301- <mark><em>COVID</em></mark> Exclusions-Heaters NARRATIVE (FINAL) 6.25",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-07-02T03:59:59Z",
#         "title": "Comment from Gina Vollmer,",
#         "openForComment": false,
#         "postedDate": "2020-06-26T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-1001"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-0809",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-06-08T04:00:00Z",
#         "highlightedContent": "Section 301- <mark><em>COVID</em></mark> Exclusions-Refrigerators NARRATIVE (final)(9532311.1)",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-06-26T03:59:59Z",
#         "title": "Comment from Gina Vollmer,",
#         "openForComment": false,
#         "postedDate": "2020-06-08T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-0809"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-1088",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-06-28T04:00:00Z",
#         "highlightedContent": "Goodman Manufacturing - <mark><em>COVID</em></mark> Exclusion Request - June 25",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-07-02T03:59:59Z",
#         "title": "Comment from Douglas Heffner, Goodman Manufacturing Company",
#         "openForComment": false,
#         "postedDate": "2020-06-28T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-1088"
#       }
#     },
#     {
#       "id": "FRA-2020-0002-0107",
#       "type": "documents",
#       "attributes": {
#         "docketId": "FRA-2020-0002",
#         "documentType": "Other",
#         "subtype": "Petition(s)",
#         "commentStartDate": "2020-09-02T04:00:00Z",
#         "highlightedContent": "42 - VMTX Emergency FRA Waiver - <mark><em>COVID</em></mark> 19",
#         "withdrawn": false,
#         "agencyId": "FRA",
#         "commentEndDate": null,
#         "title": "Virginia Museum of Transportation's 9.1.2020 Petition for Emergency Relief (Part 230)",
#         "openForComment": false,
#         "postedDate": "2020-09-02T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/FRA-2020-0002-0107"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-0740",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-05-11T04:00:00Z",
#         "highlightedContent": "VHM <mark><em>COVID</em></mark> Exemption Comment FINAL 050820",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-06-26T03:59:59Z",
#         "title": "Comment from Giorge Dalaperas, Van Horn, Metz & Co., Inc.",
#         "openForComment": false,
#         "postedDate": "2020-05-11T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-0740"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-0701",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-05-04T04:00:00Z",
#         "highlightedContent": "Zurn Industries, LLC - USTR <mark><em>COVID</em></mark> Relief Request",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": null,
#         "title": "Comment from Wesley Cline, Zurn Industries, LLC",
#         "openForComment": false,
#         "postedDate": "2020-05-04T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-0701"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-0951",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-06-26T04:00:00Z",
#         "highlightedContent": "Exclusion Request for Motors used for <mark><em>COVID</em></mark> Testing",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-07-02T03:59:59Z",
#         "title": "Comment from Joseph Spraragen, Grunfeld, Desiderio, Lebowitz, Silverman & Klestadt LLP",
#         "openForComment": false,
#         "postedDate": "2020-06-26T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-0951"
#       }
#     },
#     {
#       "id": "USTR-2020-0014-1122",
#       "type": "documents",
#       "attributes": {
#         "docketId": "USTR-2020-0014",
#         "documentType": "Other",
#         "subtype": null,
#         "commentStartDate": "2020-06-28T04:00:00Z",
#         "highlightedContent": "51039311_v 1_Positec - Gloves - 301 <mark><em>COVID</em></mark> Req.pdf",
#         "withdrawn": false,
#         "agencyId": "USTR",
#         "commentEndDate": "2020-07-02T03:59:59Z",
#         "title": "Comment from _ Positec Tool Corporation, Greenberg Traurig, LLP",
#         "openForComment": false,
#         "postedDate": "2020-06-28T04:00:00Z"
#       },
#       "links": {
#         "self": "https://api.regulations.gov/v4/documents/USTR-2020-0014-1122"
#       }
#     }
#   ],
#   "meta": {
#     "aggregations": {
#       "documentType": [
#         {
#           "docCount": 421,
#           "label": "Other"
#         },
#         {
#           "docCount": 214,
#           "label": "Notice"
#         },
#         {
#           "docCount": 117,
#           "label": "Supporting & Related Material"
#         },
#         {
#           "docCount": 77,
#           "label": "Rule"
#         },
#         {
#           "docCount": 31,
#           "label": "Proposed Rule"
#         }
#       ],
#       "subtype": [
#         {
#           "docCount": 88,
#           "label": "Answer"
#         },
#         {
#           "docCount": 51,
#           "label": "Letter(s)"
#         },
#         {
#           "docCount": 32,
#           "label": "60 Day Proposed Information Collection"
#         },
#         {
#           "docCount": 23,
#           "label": "Final Rule"
#         },
#         {
#           "docCount": 22,
#           "label": "Notice of Availability"
#         },
#         {
#           "docCount": 21,
#           "label": "Complaint"
#         },
#         {
#           "docCount": 19,
#           "label": "30 Day Proposed Information Collection"
#         },
#         {
#           "docCount": 17,
#           "label": "Background Material"
#         },
#         {
#           "docCount": 15,
#           "label": "Correspondence"
#         },
#         {
#           "docCount": 15,
#           "label": "Petition(s)"
#         },
#         {
#           "docCount": 13,
#           "label": "Request"
#         },
#         {
#           "docCount": 10,
#           "label": "Response(s)"
#         },
#         {
#           "docCount": 8,
#           "label": "Public Hearing Transcript, Deposition, Testimony"
#         },
#         {
#           "docCount": 7,
#           "label": "Additional Information"
#         },
#         {
#           "docCount": 7,
#           "label": "Report"
#         },
#         {
#           "docCount": 7,
#           "label": "Waiver"
#         },
#         {
#           "docCount": 6,
#           "label": "Data"
#         },
#         {
#           "docCount": 6,
#           "label": "ICR Supporting Statement"
#         },
#         {
#           "docCount": 6,
#           "label": "Proposal(s)"
#         },
#         {
#           "docCount": 6,
#           "label": "Supplement"
#         },
#         {
#           "docCount": 6,
#           "label": "Transcript"
#         },
#         {
#           "docCount": 5,
#           "label": "Application"
#         },
#         {
#           "docCount": 5,
#           "label": "Form"
#         },
#         {
#           "docCount": 5,
#           "label": "Motion"
#         },
#         {
#           "docCount": 4,
#           "label": "Announcement"
#         },
#         {
#           "docCount": 4,
#           "label": "Request for Comments"
#         },
#         {
#           "docCount": 3,
#           "label": "Application-Other"
#         },
#         {
#           "docCount": 3,
#           "label": "Decision"
#         },
#         {
#           "docCount": 3,
#           "label": "Interagency Review"
#         },
#         {
#           "docCount": 3,
#           "label": "Notice of Intent"
#         },
#         {
#           "docCount": 3,
#           "label": "Objection(s)"
#         },
#         {
#           "docCount": 3,
#           "label": "Request for Hearing"
#         },
#         {
#           "docCount": 3,
#           "label": "Transcript(s)"
#         },
#         {
#           "docCount": 3,
#           "label": "Withdrawal"
#         },
#         {
#           "docCount": 2,
#           "label": "Approval"
#         },
#         {
#           "docCount": 2,
#           "label": "Certifications"
#         },
#         {
#           "docCount": 2,
#           "label": "Citizen Petition"
#         },
#         {
#           "docCount": 2,
#           "label": "Comment Response"
#         },
#         {
#           "docCount": 2,
#           "label": "Direct Final Rule"
#         },
#         {
#           "docCount": 2,
#           "label": "General Notice"
#         },
#         {
#           "docCount": 2,
#           "label": "Guidance"
#         },
#         {
#           "docCount": 2,
#           "label": "Interim Final Rule"
#         },
#         {
#           "docCount": 2,
#           "label": "Letter"
#         },
#         {
#           "docCount": 2,
#           "label": "Meeting Transcripts"
#         },
#         {
#           "docCount": 2,
#           "label": "Memorandum"
#         },
#         {
#           "docCount": 2,
#           "label": "Notice of Proposed Rulemaking (NPRM)"
#         },
#         {
#           "docCount": 2,
#           "label": "Order"
#         },
#         {
#           "docCount": 2,
#           "label": "Petition"
#         },
#         {
#           "docCount": 2,
#           "label": "Rebuttal"
#         },
#         {
#           "docCount": 2,
#           "label": "Supplement (SUP)"
#         },
#         {
#           "docCount": 1,
#           "label": "Advisory Committee"
#         },
#         {
#           "docCount": 1,
#           "label": "Amendment"
#         },
#         {
#           "docCount": 1,
#           "label": "Analysis"
#         },
#         {
#           "docCount": 1,
#           "label": "Appendix"
#         },
#         {
#           "docCount": 1,
#           "label": "Consent"
#         },
#         {
#           "docCount": 1,
#           "label": "Consolidated Answer"
#         },
#         {
#           "docCount": 1,
#           "label": "Correction"
#         },
#         {
#           "docCount": 1,
#           "label": "E-mail"
#         },
#         {
#           "docCount": 1,
#           "label": "Extension of Comment Period"
#         },
#         {
#           "docCount": 1,
#           "label": "Letter(s) in Support"
#         },
#         {
#           "docCount": 1,
#           "label": "MI-Minutes of Meeting"
#         },
#         {
#           "docCount": 1,
#           "label": "Meeting Materials"
#         },
#         {
#           "docCount": 1,
#           "label": "Memo"
#         },
#         {
#           "docCount": 1,
#           "label": "Motion/Reply"
#         },
#         {
#           "docCount": 1,
#           "label": "Notice of Interim Rule"
#         },
#         {
#           "docCount": 1,
#           "label": "Office of Management and Budget (OMB)"
#         },
#         {
#           "docCount": 1,
#           "label": "Opposition"
#         },
#         {
#           "docCount": 1,
#           "label": "Record of Meeting/Phone Conversation"
#         },
#         {
#           "docCount": 1,
#           "label": "References"
#         },
#         {
#           "docCount": 1,
#           "label": "References/Supporting Documents"
#         },
#         {
#           "docCount": 1,
#           "label": "Reply"
#         },
#         {
#           "docCount": 1,
#           "label": "Research, Technology, Education"
#         },
#         {
#           "docCount": 1,
#           "label": "Speech"
#         },
#         {
#           "docCount": 1,
#           "label": "Statement"
#         },
#         {
#           "docCount": 1,
#           "label": "System of Records"
#         },
#         {
#           "docCount": 1,
#           "label": "TR-Transcript"
#         },
#         {
#           "docCount": 1,
#           "label": "Transcripts"
#         }
#       ],
#       "withinCommentPeriod": [
#         {
#           "docCount": 35,
#           "label": "true"
#         },
#         {
#           "docCount": 825,
#           "label": "false"
#         }
#       ],
#       "agencyId": [
#         {
#           "docCount": 156,
#           "value": "DOT"
#         },
#         {
#           "docCount": 128,
#           "value": "USTR"
#         },
#         {
#           "docCount": 120,
#           "value": "EPA"
#         },
#         {
#           "docCount": 84,
#           "value": "FAA"
#         },
#         {
#           "docCount": 63,
#           "value": "ED"
#         },
#         {
#           "docCount": 59,
#           "value": "FDA"
#         },
#         {
#           "docCount": 53,
#           "value": "CDC"
#         },
#         {
#           "docCount": 25,
#           "value": "FRA"
#         },
#         {
#           "docCount": 17,
#           "value": "CMS"
#         },
#         {
#           "docCount": 16,
#           "value": "CRC"
#         },
#         {
#           "docCount": 10,
#           "value": "BIS"
#         },
#         {
#           "docCount": 10,
#           "value": "NRC"
#         },
#         {
#           "docCount": 9,
#           "value": "FWS"
#         },
#         {
#           "docCount": 8,
#           "value": "NOAA"
#         },
#         {
#           "docCount": 8,
#           "value": "USBC"
#         },
#         {
#           "docCount": 7,
#           "value": "OSHA"
#         },
#         {
#           "docCount": 6,
#           "value": "PHMSA"
#         },
#         {
#           "docCount": 5,
#           "value": "FTA"
#         },
#         {
#           "docCount": 5,
#           "value": "PC"
#         },
#         {
#           "docCount": 5,
#           "value": "VA"
#         },
#         {
#           "docCount": 4,
#           "value": "FMCSA"
#         },
#         {
#           "docCount": 4,
#           "value": "NSF"
#         },
#         {
#           "docCount": 4,
#           "value": "USCBP"
#         },
#         {
#           "docCount": 4,
#           "value": "USCIS"
#         },
#         {
#           "docCount": 3,
#           "value": "FRS"
#         },
#         {
#           "docCount": 3,
#           "value": "FSA"
#         },
#         {
#           "docCount": 3,
#           "value": "OCC"
#         },
#         {
#           "docCount": 2,
#           "value": "COE"
#         },
#         {
#           "docCount": 2,
#           "value": "EERE"
#         },
#         {
#           "docCount": 2,
#           "value": "FDIC"
#         },
#         {
#           "docCount": 2,
#           "value": "FEMA"
#         },
#         {
#           "docCount": 2,
#           "value": "FHWA"
#         },
#         {
#           "docCount": 2,
#           "value": "HHS"
#         },
#         {
#           "docCount": 2,
#           "value": "NCUA"
#         },
#         {
#           "docCount": 2,
#           "value": "RBS"
#         },
#         {
#           "docCount": 2,
#           "value": "SBA"
#         },
#         {
#           "docCount": 2,
#           "value": "SEC"
#         },
#         {
#           "docCount": 2,
#           "value": "SSA"
#         },
#         {
#           "docCount": 2,
#           "value": "TREAS"
#         },
#         {
#           "docCount": 1,
#           "value": "APHIS"
#         },
#         {
#           "docCount": 1,
#           "value": "BOP"
#         },
#         {
#           "docCount": 1,
#           "value": "CFPB"
#         },
#         {
#           "docCount": 1,
#           "value": "CFTC"
#         },
#         {
#           "docCount": 1,
#           "value": "CPSC"
#         },
#         {
#           "docCount": 1,
#           "value": "DEA"
#         },
#         {
#           "docCount": 1,
#           "value": "DOI"
#         },
#         {
#           "docCount": 1,
#           "value": "DOL"
#         },
#         {
#           "docCount": 1,
#           "value": "EBSA"
#         },
#         {
#           "docCount": 1,
#           "value": "ETA"
#         },
#         {
#           "docCount": 1,
#           "value": "FERC"
#         },
#         {
#           "docCount": 1,
#           "value": "MARAD"
#         },
#         {
#           "docCount": 1,
#           "value": "NARA"
#         },
#         {
#           "docCount": 1,
#           "value": "NHTSA"
#         },
#         {
#           "docCount": 1,
#           "value": "RHS"
#         },
#         {
#           "docCount": 1,
#           "value": "RUS"
#         },
#         {
#           "docCount": 1,
#           "value": "TVA"
#         }
#       ],
#       "commentEndDate": [
#         {
#           "docCount": 2,
#           "label": "Today",
#           "fromDate": "2020-11-02 00:00:00",
#           "toDate": "2020-11-02 23:59:59"
#         },
#         {
#           "docCount": 4,
#           "label": "Next 3 Days",
#           "fromDate": "2020-11-02 00:00:00",
#           "toDate": "2020-11-04 23:59:59"
#         },
#         {
#           "docCount": 4,
#           "label": "Next 7 Days",
#           "fromDate": "2020-11-02 00:00:00",
#           "toDate": "2020-11-08 23:59:59"
#         },
#         {
#           "docCount": 11,
#           "label": "Next 15 Days",
#           "fromDate": "2020-11-02 00:00:00",
#           "toDate": "2020-11-16 23:59:59"
#         },
#         {
#           "docCount": 22,
#           "label": "Next 30 Days",
#           "fromDate": "2020-11-02 00:00:00",
#           "toDate": "2020-12-01 23:59:59"
#         },
#         {
#           "docCount": 35,
#           "label": "Next 90 Days",
#           "fromDate": "2020-11-02 00:00:00",
#           "toDate": "2021-01-30 23:59:59"
#         }
#       ],
#       "postedDate": [
#         {
#           "docCount": 5,
#           "label": "Today",
#           "fromDate": "2020-11-02 00:00:00",
#           "toDate": "2020-11-02 23:59:59"
#         },
#         {
#           "docCount": 5,
#           "label": "Last 3 Days",
#           "fromDate": "2020-10-31 00:00:00",
#           "toDate": "2020-11-02 23:59:59"
#         },
#         {
#           "docCount": 16,
#           "label": "Last 7 Days",
#           "fromDate": "2020-10-27 00:00:00",
#           "toDate": "2020-11-02 23:59:59"
#         },
#         {
#           "docCount": 41,
#           "label": "Last 15 Days",
#           "fromDate": "2020-10-19 00:00:00",
#           "toDate": "2020-11-02 23:59:59"
#         },
#         {
#           "docCount": 92,
#           "label": "Last 30 Days",
#           "fromDate": "2020-10-04 00:00:00",
#           "toDate": "2020-11-02 23:59:59"
#         },
#         {
#           "docCount": 319,
#           "label": "Last 90 Days",
#           "fromDate": "2020-08-05 00:00:00",
#           "toDate": "2020-11-02 23:59:59"
#         }
#       ]
#     },
#     "filters": {},
#     "hasNextPage": true,
#     "hasPreviousPage": false,
#     "numberOfElements": 25,
#     "pageNumber": 1,
#     "pageSize": 25,
#     "totalElements": 860,
#     "totalPages": 20,
#     "firstPage": true,
#     "lastPage": false
#   }
# }
